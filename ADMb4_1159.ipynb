# %% [markdown]
# <a href="https://colab.research.google.com/github/PatelHarshit/ADM-lab/blob/main/ADMb4_1159.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10,5,7])

plt.plot(ypoints)
plt.show()

# %%
ypoints = np.array([0,3,8,1,10,5,7])
plt.plot(ypoints,'o-r')
plt.show()

# %%
plt.plot(ypoints, ls = ':')
plt.plot(ypoints, color = 'r')
plt.plot(ypoints, linewidth ='20.5')

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 7, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
plt.plot(ypoints,marker='o',ms=20,mec='royalblue',mfc='yellow')
plt.plot(ypoints,ls=':')
plt.plot(ypoints,color='r')
plt.plot(ypoints,linewidth='20.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["А", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %%
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel ("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
plt.grid()
plt.grid(axis='x')
plt.grid(axis='y')

# %%
plt.grid(axis='x')

# %%
plt.grid(axis='y')

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170, 10, 250)

plt.hist(x)
plt.show()

# %%
x1=np.array([0,1,2,3])
y1=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x1,y1)
x2=np.array([0,1,2,3])
y2=np.array([10,1,6,8])
plt.subplot(2,1,2)
plt.plot(x2,y2)
plt.show()
